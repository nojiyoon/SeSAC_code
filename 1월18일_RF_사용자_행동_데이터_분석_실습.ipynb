# %% [markdown]
# <a href="https://colab.research.google.com/github/nojiyoon/SeSAC_code/blob/main/1%EC%9B%9418%EC%9D%BC_RF_%EC%82%AC%EC%9A%A9%EC%9E%90_%ED%96%89%EB%8F%99_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터셋
# http://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones

# %%
import pandas as pd

# %%
feature_name_df = pd.read_csv('human_activity_features.txt',
                              sep='\s+', # 데이터 사이에 공백이 있다고 알려줌
                              header=None,
                              names=['column_index', 'column_name'])

# %%
feature_name_df
# Out:
#      column_index                           column_name
# 0               1                     tBodyAcc-mean()-X
# 1               2                     tBodyAcc-mean()-Y
# 2               3                     tBodyAcc-mean()-Z
# 3               4                      tBodyAcc-std()-X
# 4               5                      tBodyAcc-std()-Y
# ..            ...                                   ...
# 556           557      angle(tBodyGyroMean,gravityMean)
# 557           558  angle(tBodyGyroJerkMean,gravityMean)
# 558           559                  angle(X,gravityMean)
# 559           560                  angle(Y,gravityMean)
# 560           561                  angle(Z,gravityMean)
#
# [561 rows x 2 columns]

# %%
feature_name_df.iloc[:,1]
# Out:
# 0                         tBodyAcc-mean()-X
# 1                         tBodyAcc-mean()-Y
# 2                         tBodyAcc-mean()-Z
# 3                          tBodyAcc-std()-X
# 4                          tBodyAcc-std()-Y
#                        ...
# 556        angle(tBodyGyroMean,gravityMean)
# 557    angle(tBodyGyroJerkMean,gravityMean)
# 558                    angle(X,gravityMean)
# 559                    angle(Y,gravityMean)
# 560                    angle(Z,gravityMean)
# Name: column_name, Length: 561, dtype: object

# %%
feature_name_df.iloc[:,1].values
# Out:
# array(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z',
#        'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z',
#        'tBodyAcc-sma()', 'tBodyAcc-energy()-X', 'tBodyAcc-energy()-Y',
#        'tBodyAcc-energy()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y',
#        'tBodyAcc-iqr()-Z', 'tBodyAcc-entropy()-X', 'tBodyAcc-entropy()-Y',
#        'tBodyAcc-entropy()-Z', 'tBodyAcc-arCoeff()-X,1',
#        'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3',
#        'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1',
#        'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3',
#        'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1',
#        'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3',
#        'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y',
# ...

# %%
feature_name = feature_name_df.iloc[:,1].values.tolist()
feature_name
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %%
X_train = pd.read_csv('human_activity_X_train.txt', sep='\s+', header=None)
X_train
# Out:
#            0         1         2    ...       558       559       560
# 0     0.288585 -0.020294 -0.132905  ... -0.841247  0.179941 -0.058627
# 1     0.278419 -0.016411 -0.123520  ... -0.844788  0.180289 -0.054317
# 2     0.279653 -0.019467 -0.113462  ... -0.848933  0.180637 -0.049118
# 3     0.279174 -0.026201 -0.123283  ... -0.848649  0.181935 -0.047663
# 4     0.276629 -0.016570 -0.115362  ... -0.847865  0.185151 -0.043892
# ...        ...       ...       ...  ...       ...       ...       ...
# 7347  0.299665 -0.057193 -0.181233  ... -0.791883  0.238604  0.049819
# 7348  0.273853 -0.007749 -0.147468  ... -0.771840  0.252676  0.050053
# 7349  0.273387 -0.017011 -0.045022  ... -0.779133  0.249145  0.040811
# 7350  0.289654 -0.018843 -0.158281  ... -0.785181  0.246432  0.025339
# 7351  0.351503 -0.012423 -0.203867  ... -0.783267  0.246809  0.036695
#
# [7352 rows x 561 columns]

# %%
X_train.columns=feature_name
X_train
# Out:
#       tBodyAcc-mean()-X  ...  angle(Z,gravityMean)
# 0              0.288585  ...             -0.058627
# 1              0.278419  ...             -0.054317
# 2              0.279653  ...             -0.049118
# 3              0.279174  ...             -0.047663
# 4              0.276629  ...             -0.043892
# ...                 ...  ...                   ...
# 7347           0.299665  ...              0.049819
# 7348           0.273853  ...              0.050053
# 7349           0.273387  ...              0.040811
# 7350           0.289654  ...              0.025339
# 7351           0.351503  ...              0.036695
#
# [7352 rows x 561 columns]

# %%
X_train.describe()
# Out:
#        tBodyAcc-mean()-X  ...  angle(Z,gravityMean)
# count        7352.000000  ...           7352.000000
# mean            0.274488  ...             -0.056515
# std             0.070261  ...              0.279122
# min            -1.000000  ...             -1.000000
# 25%             0.262975  ...             -0.143414
# 50%             0.277193  ...              0.003181
# 75%             0.288461  ...              0.107659
# max             1.000000  ...              1.000000
#
# [8 rows x 561 columns]

# %%
X_test = pd.read_csv('human_activity_X_test.txt', sep='\s+', header=None)
X_test
# Out:
#            0         1         2    ...       558       559       560
# 0     0.257178 -0.023285 -0.014654  ... -0.720009  0.276801 -0.057978
# 1     0.286027 -0.013163 -0.119083  ... -0.698091  0.281343 -0.083898
# 2     0.275485 -0.026050 -0.118152  ... -0.702771  0.280083 -0.079346
# 3     0.270298 -0.032614 -0.117520  ... -0.698954  0.284114 -0.077108
# 4     0.274833 -0.027848 -0.129527  ... -0.692245  0.290722 -0.073857
# ...        ...       ...       ...  ...       ...       ...       ...
# 2942  0.310155 -0.053391 -0.099109  ... -0.651732  0.274627  0.184784
# 2943  0.363385 -0.039214 -0.105915  ... -0.655181  0.273578  0.182412
# 2944  0.349966  0.030077 -0.115788  ... -0.655357  0.274479  0.181184
# 2945  0.237594  0.018467 -0.096499  ... -0.659719  0.264782  0.187563
# 2946  0.153627 -0.018437 -0.137018  ... -0.660080  0.263936  0.188103
#
# [2947 rows x 561 columns]

# %%
X_test.columns=feature_name
X_test
# Out:
#       tBodyAcc-mean()-X  ...  angle(Z,gravityMean)
# 0              0.257178  ...             -0.057978
# 1              0.286027  ...             -0.083898
# 2              0.275485  ...             -0.079346
# 3              0.270298  ...             -0.077108
# 4              0.274833  ...             -0.073857
# ...                 ...  ...                   ...
# 2942           0.310155  ...              0.184784
# 2943           0.363385  ...              0.182412
# 2944           0.349966  ...              0.181184
# 2945           0.237594  ...              0.187563
# 2946           0.153627  ...              0.188103
#
# [2947 rows x 561 columns]

# %%
y_train = pd.read_csv('human_activity_y_train.txt', sep='\s+', header=None, names=['action'])
y_train
# Out:
#       action
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 7347       2
# 7348       2
# 7349       2
# 7350       2
# 7351       2
#
# [7352 rows x 1 columns]

# %%
y_test = pd.read_csv('human_activity_y_test.txt', sep='\s+', header=None, names=['action'])
y_test
# Out:
#       action
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 2942       2
# 2943       2
# 2944       2
# 2945       2
# 2946       2
#
# [2947 rows x 1 columns]

# %%
y_train.action.value_counts()
# Out:
# 6    1407
# 5    1374
# 4    1286
# 1    1226
# 2    1073
# 3     986
# Name: action, dtype: int64

# %%
X_train.isnull().sum()
# Out:
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
#                                        ..
# angle(tBodyGyroMean,gravityMean)        0
# angle(tBodyGyroJerkMean,gravityMean)    0
# angle(X,gravityMean)                    0
# angle(Y,gravityMean)                    0
# angle(Z,gravityMean)                    0
# Length: 561, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
import numpy as np

# %%
rf_clf = RandomForestClassifier()
rf_clf
# Out:
# RandomForestClassifier()

# %%
rf_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier()

# %%
pred = rf_clf.predict(X_test)
pred
# Out:
# array([5, 5, 5, ..., 2, 2, 1])

# %%
accuracy = accuracy_score(y_test, pred)
print('랜덤 포레스트 정확도: ', accuracy)
# Out:
# 랜덤 포레스트 정확도:  0.9229725144214456
